# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
df=pd.read_csv('diabetes.csv')

# %%
df.shape
# Out:
# (768, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
X=df.drop(['Outcome'],axis=1)
y=df['Outcome']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=1)

# %%
dt_classi=DecisionTreeClassifier()

# %%
dt_classi.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
plt.figure(figsize=(20,15))
tree.plot_tree(dt_classifier,filled=True,class_names=True)
# Out:
# [Text(0.5, 0.9, 'X[1] <= 127.5\nentropy = 0.926\nsamples = 537\nvalue = [354, 183]\nclass = y[0]'),
#  Text(0.25, 0.7, 'X[5] <= 26.45\nentropy = 0.72\nsamples = 342\nvalue = [274, 68]\nclass = y[0]'),
#  Text(0.125, 0.5, 'X[5] <= 9.1\nentropy = 0.201\nsamples = 96\nvalue = [93, 3]\nclass = y[0]'),
#  Text(0.0625, 0.3, 'X[0] <= 7.5\nentropy = 0.918\nsamples = 6\nvalue = [4, 2]\nclass = y[0]'),
#  Text(0.03125, 0.1, 'entropy = 0.0\nsamples = 4\nvalue = [4, 0]\nclass = y[0]'),
#  Text(0.09375, 0.1, 'entropy = 0.0\nsamples = 2\nvalue = [0, 2]\nclass = y[1]'),
#  Text(0.1875, 0.3, 'X[6] <= 0.669\nentropy = 0.088\nsamples = 90\nvalue = [89, 1]\nclass = y[0]'),
#  Text(0.15625, 0.1, 'entropy = 0.0\nsamples = 75\nvalue = [75, 0]\nclass = y[0]'),
#  Text(0.21875, 0.1, 'entropy = 0.353\nsamples = 15\nvalue = [14, 1]\nclass = y[0]'),
#  Text(0.375, 0.5, 'X[7] <= 27.5\nentropy = 0.833\nsamples = 246\nvalue = [181, 65]\nclass = y[0]'),
#  Text(0.3125, 0.3, 'X[5] <= 30.95\nentropy = 0.544\nsamples = 112\nvalue = [98, 14]\nclass = y[0]'),
#  Text(0.28125, 0.1, 'entropy = 0.159\nsamples = 43\nvalue = [42, 1]\nclass = y[0]'),
#  Text(0.34375, 0.1, 'entropy = 0.698\nsamples = 69\nvalue = [56, 13]\nclass = y[0]'),
#  Text(0.4375, 0.3, 'X[1] <= 89.5\nentropy = 0.958\nsamples = 134\nvalue = [83, 51]\nclass = y[0]'),
#  Text(0.40625, 0.1, 'entropy = 0.267\nsamples = 22\nvalue = [21, 1]\nclass = y[0]'),
#  Text(0.46875, 0.1, 'entropy = 0.992\nsamples = 112\nvalue = [62, 50]\nclass = y[0]'),
#  Text(0.75, 0.7, 'X[5] <= 28.15\nentropy = 0.977\nsamples = 195\nvalue = [80, 115]\nclass = y[1]'),
#  Text(0.625, 0.5, 'X[1] <= 145.5\nentropy = 0.82\nsamples = 43\nvalue = [32, 11]\nclass = y[0]'),
#  Text(0.5625, 0.3, 'X[2] <= 73.0\nentropy = 0.402\nsamples = 25\nvalue = [23, 2]\nclass = y[0]'),
#  Text(0.53125, 0.1, 'entropy = 0.722\nsamples = 10\nvalue = [8, 2]\nclass = y[0]'),
#  Text(0.59375, 0.1, 'entropy = 0.0\nsamples = 15\nvalue = [15, 0]\nclass = y[0]'),
#  Text(0.6875, 0.3, 'X[7] <= 25.5\nentropy = 1.0\nsamples = 18\nvalue = [9, 9]\nclass = y[0]'),
#  Text(0.65625, 0.1, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0]\nclass = y[0]'),
#  Text(0.71875, 0.1, 'entropy = 0.971\nsamples = 15\nvalue = [6, 9]\nclass = y[1]'),
#  Text(0.875, 0.5, 'X[1] <= 158.5\nentropy = 0.9\nsamples = 152\nvalue = [48, 104]\nclass = y[1]'),
#  Text(0.8125, 0.3, 'X[7] <= 30.5\nentropy = 0.985\nsamples = 96\nvalue = [41, 55]\nclass = y[1]'),
#  Text(0.78125, 0.1, 'entropy = 0.984\nsamples = 47\nvalue = [27, 20]\nclass = y[0]'),
#  Text(0.84375, 0.1, 'entropy = 0.863\nsamples = 49\nvalue = [14, 35]\nclass = y[1]'),
#  Text(0.9375, 0.3, 'X[7] <= 30.5\nentropy = 0.544\nsamples = 56\nvalue = [7, 49]\nclass = y[1]'),
#  Text(0.90625, 0.1, 'entropy = 0.0\nsamples = 20\nvalue = [0, 20]\nclass = y[1]'),
#  Text(0.96875, 0.1, 'entropy = 0.711\nsamples = 36\nvalue = [7, 29]\nclass = y[1]')]

# %%
dt_classifier = DecisionTreeClassifier(criterion="entropy",max_depth=4)
dt_classifier.fit(X_train,y_train)

score = dt_classifier.score(X_train,y_train)
print("R-squared Train  :", score)

score = dt_classifier.score(X_test, y_test)
print("R-squared Test  :", score)

y_pred = dt_classifier.predict(X_test)

mse = mean_squared_error(y_test,y_pred)
print("MSE :",mse)
print("RMSE :",mse**(1/2.0))
# Out:
# R-squared Train  : 0.7858472998137802
# R-squared Test  : 0.7922077922077922
# MSE : 0.2077922077922078
# RMSE : 0.4558423058385518

# %% [markdown]
# Regression Problem with Decission Tree
